# %%
import keras
from keras.datasets import cifar10
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
import scipy
from scipy import misc
import os

# load the data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = np.squeeze(y_train)
print('data loaded')

# load VGG16 model + remove final classification layers
I_R=64
model = VGG16(weights='imagenet', include_top=False, input_shape=(I_R,I_R, 3))
model.summary()
print('model loaded')
# Out:
# data loaded
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# model loaded

# %%
# obtain bottleneck features (train)
if os.path.exists('vgg16_features_train.npz'):
    print('bottleneck features detected (train)')
    features = np.load('vgg16_features_train.npz')['features']
else:
  # obtain bottleneck features (train)
  print('bottleneck features file not detected (train)')
  print('calculating now ...')
  # pre-process the train data
  big_x_train = np.array([scipy.misc.imresize(x_train[i], (I_R,I_R, 3)) 
                     for i in range(0, len(x_train))]).astype('float32')
  inception_input_train = preprocess_input(big_x_train)
  print('train data prepsrocessed')
  # extract, process, and save bottleneck features
  features = model.predict(inception_input_train)
  features = np.squeeze(features)
  np.savez('vgg16_features_train', features=features)
print('bottleneck features saved (train)')
# Out:
# bottleneck features detected (train)
# bottleneck features saved (train)

# %%
# obtain bottleneck features (test)
if os.path.exists('vgg16_features_test.npz'):
    print('bottleneck features detected (test)')
    features_test = np.load('vgg16_features_test.npz')['features_test']
else:
  print('bottleneck features file not detected (test)')
  print('calculating now ...')
  # pre-process the test data
  big_x_test = np.array([scipy.misc.imresize(x_test[i], (I_R,I_R, 3)) 
                     for i in range(0, len(x_test))]).astype('float32')
  inception_input_test = preprocess_input(big_x_test)
  # extract, process, and save bottleneck features (test)
  features_test = model.predict(inception_input_test)
  features_test = np.squeeze(features_test)
  np.savez('vgg16_features_test', features_test=features_test)
print('bottleneck features saved (test)')
# Out:
# bottleneck features detected (test)
# bottleneck features saved (test)

# %%
from keras.utils import np_utils

# one-hot encode the labels
y_train = np_utils.to_categorical(y_train, 10)
y_test = np_utils.to_categorical(y_test, 10)

# %%
from keras.callbacks import ModelCheckpoint   
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, GlobalAveragePooling2D

model = Sequential()
model.add(Conv2D(filters=100, kernel_size=2, input_shape=features.shape[1:]))
model.add(Dropout(0.4))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='cnn_vgg16_model.best.hdf5', 
                               verbose=1, save_best_only=True)
model.fit(features, y_train, batch_size=50, epochs=50,
          validation_split=0.2, callbacks=[checkpointer],
          verbose=2, shuffle=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 1, 1, 100)         204900
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 100)         0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 100)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 205,910
# Trainable params: 205,910
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
#  - 5s - loss: 5.8290 - acc: 0.5961 - val_loss: 4.0609 - val_acc: 0.7154
#
# Epoch 00001: val_loss improved from inf to 4.06088, saving model to cnn_vgg16_model.best.hdf5
# Epoch 2/50
#  - 5s - loss: 4.5406 - acc: 0.6903 - val_loss: 3.7989 - val_acc: 0.7406
#
# Epoch 00002: val_loss improved from 4.06088 to 3.79891, saving model to cnn_vgg16_model.best.hdf5
# Epoch 3/50
#  - 5s - loss: 4.2763 - acc: 0.7101 - val_loss: 3.9664 - val_acc: 0.7323
#
# Epoch 00003: val_loss did not improve
# Epoch 4/50
#  - 5s - loss: 4.1382 - acc: 0.7237 - val_loss: 3.8915 - val_acc: 0.7388
#
# Epoch 00004: val_loss did not improve
# Epoch 5/50
#  - 5s - loss: 4.0784 - acc: 0.7282 - val_loss: 3.6223 - val_acc: 0.7595
#
# Epoch 00005: val_loss improved from 3.79891 to 3.62230, saving model to cnn_vgg16_model.best.hdf5
# Epoch 6/50
#  - 5s - loss: 3.9854 - acc: 0.7354 - val_loss: 3.6560 - val_acc: 0.7558
#
# Epoch 00006: val_loss did not improve
# Epoch 7/50
#  - 5s - loss: 3.9418 - acc: 0.7384 - val_loss: 3.5432 - val_acc: 0.7644
#
# Epoch 00007: val_loss improved from 3.62230 to 3.54318, saving model to cnn_vgg16_model.best.hdf5
# Epoch 8/50
#  - 5s - loss: 3.8832 - acc: 0.7432 - val_loss: 3.6755 - val_acc: 0.7549
#
# Epoch 00008: val_loss did not improve
# Epoch 9/50
#  - 5s - loss: 3.8471 - acc: 0.7453 - val_loss: 3.5701 - val_acc: 0.7632
#
# Epoch 00009: val_loss did not improve
# Epoch 10/50
#  - 5s - loss: 3.7978 - acc: 0.7491 - val_loss: 3.5594 - val_acc: 0.7652
#
# Epoch 00010: val_loss did not improve
# Epoch 11/50
#  - 5s - loss: 3.7550 - acc: 0.7516 - val_loss: 3.5344 - val_acc: 0.7660
#
# Epoch 00011: val_loss improved from 3.54318 to 3.53445, saving model to cnn_vgg16_model.best.hdf5
# Epoch 12/50
#  - 5s - loss: 3.7173 - acc: 0.7564 - val_loss: 3.5229 - val_acc: 0.7672
#
# Epoch 00012: val_loss improved from 3.53445 to 3.52286, saving model to cnn_vgg16_model.best.hdf5
# Epoch 13/50
#  - 5s - loss: 3.7631 - acc: 0.7536 - val_loss: 3.5335 - val_acc: 0.7686
#
# Epoch 00013: val_loss did not improve
# Epoch 14/50
#  - 5s - loss: 3.7323 - acc: 0.7560 - val_loss: 3.6402 - val_acc: 0.7605
#
# Epoch 00014: val_loss did not improve
# Epoch 15/50
#  - 5s - loss: 3.6931 - acc: 0.7583 - val_loss: 3.5128 - val_acc: 0.7700
#
# Epoch 00015: val_loss improved from 3.52286 to 3.51284, saving model to cnn_vgg16_model.best.hdf5
# Epoch 16/50
#  - 5s - loss: 3.6847 - acc: 0.7599 - val_loss: 3.5566 - val_acc: 0.7665
#
# Epoch 00016: val_loss did not improve
# Epoch 17/50
#  - 5s - loss: 3.6694 - acc: 0.7604 - val_loss: 3.5413 - val_acc: 0.7703
#
# Epoch 00017: val_loss did not improve
# Epoch 18/50
#  - 5s - loss: 3.6363 - acc: 0.7628 - val_loss: 3.4808 - val_acc: 0.7731
#
# Epoch 00018: val_loss improved from 3.51284 to 3.48081, saving model to cnn_vgg16_model.best.hdf5
# Epoch 19/50
#  - 5s - loss: 3.6271 - acc: 0.7643 - val_loss: 3.5852 - val_acc: 0.7662
#
# Epoch 00019: val_loss did not improve
# Epoch 20/50
#  - 5s - loss: 3.6330 - acc: 0.7642 - val_loss: 3.6011 - val_acc: 0.7668
#
# Epoch 00020: val_loss did not improve
# Epoch 21/50
#  - 5s - loss: 3.6309 - acc: 0.7643 - val_loss: 3.4294 - val_acc: 0.7769
#
# Epoch 00021: val_loss improved from 3.48081 to 3.42944, saving model to cnn_vgg16_model.best.hdf5
# Epoch 22/50
#  - 5s - loss: 3.5851 - acc: 0.7670 - val_loss: 3.4470 - val_acc: 0.7752
#
# Epoch 00022: val_loss did not improve
# Epoch 23/50
#  - 5s - loss: 3.5829 - acc: 0.7681 - val_loss: 3.4603 - val_acc: 0.7744
#
# Epoch 00023: val_loss did not improve
# Epoch 24/50
#  - 5s - loss: 3.6138 - acc: 0.7664 - val_loss: 3.5247 - val_acc: 0.7720
#
# Epoch 00024: val_loss did not improve
# Epoch 25/50
#  - 5s - loss: 3.6038 - acc: 0.7664 - val_loss: 3.5159 - val_acc: 0.7710
#
# Epoch 00025: val_loss did not improve
# Epoch 26/50
#  - 5s - loss: 3.6050 - acc: 0.7677 - val_loss: 3.5034 - val_acc: 0.7733
#
# Epoch 00026: val_loss did not improve
# Epoch 27/50
#  - 5s - loss: 3.5988 - acc: 0.7677 - val_loss: 3.5196 - val_acc: 0.7719
#
# Epoch 00027: val_loss did not improve
# Epoch 28/50
#  - 5s - loss: 3.5858 - acc: 0.7686 - val_loss: 3.5573 - val_acc: 0.7707
#
# Epoch 00028: val_loss did not improve
# Epoch 29/50
#  - 5s - loss: 3.5756 - acc: 0.7685 - val_loss: 3.6019 - val_acc: 0.7682
#
# Epoch 00029: val_loss did not improve
# Epoch 30/50
#  - 5s - loss: 3.5832 - acc: 0.7692 - val_loss: 3.5144 - val_acc: 0.7742
#
# Epoch 00030: val_loss did not improve
# Epoch 31/50
#  - 5s - loss: 3.5679 - acc: 0.7702 - val_loss: 3.5357 - val_acc: 0.7723
#
# Epoch 00031: val_loss did not improve
# Epoch 32/50
#  - 5s - loss: 3.5744 - acc: 0.7709 - val_loss: 3.5801 - val_acc: 0.7696
#
# Epoch 00032: val_loss did not improve
# Epoch 33/50
#  - 5s - loss: 3.5773 - acc: 0.7698 - val_loss: 3.4798 - val_acc: 0.7764
#
# Epoch 00033: val_loss did not improve
# Epoch 34/50
#  - 5s - loss: 3.5137 - acc: 0.7737 - val_loss: 3.5174 - val_acc: 0.7730
#
# Epoch 00034: val_loss did not improve
# Epoch 35/50
#  - 5s - loss: 3.4935 - acc: 0.7753 - val_loss: 3.5323 - val_acc: 0.7740
#
# Epoch 00035: val_loss did not improve
# Epoch 36/50
#  - 5s - loss: 3.5038 - acc: 0.7742 - val_loss: 3.4819 - val_acc: 0.7757
#
# Epoch 00036: val_loss did not improve
# Epoch 37/50
#  - 5s - loss: 3.5495 - acc: 0.7722 - val_loss: 3.5550 - val_acc: 0.7732
#
# Epoch 00037: val_loss did not improve
# Epoch 38/50
#  - 5s - loss: 3.5392 - acc: 0.7732 - val_loss: 3.5574 - val_acc: 0.7719
#
# Epoch 00038: val_loss did not improve
# Epoch 39/50
#  - 5s - loss: 3.5431 - acc: 0.7731 - val_loss: 3.5617 - val_acc: 0.7715
#
# Epoch 00039: val_loss did not improve
# Epoch 40/50
#  - 5s - loss: 3.4984 - acc: 0.7758 - val_loss: 3.5411 - val_acc: 0.7738
#
# Epoch 00040: val_loss did not improve
# Epoch 41/50
#  - 5s - loss: 3.5320 - acc: 0.7735 - val_loss: 3.5756 - val_acc: 0.7720
#
# Epoch 00041: val_loss did not improve
# Epoch 42/50
#  - 5s - loss: 3.4799 - acc: 0.7774 - val_loss: 3.4965 - val_acc: 0.7769
#
# Epoch 00042: val_loss did not improve
# Epoch 43/50
#  - 5s - loss: 3.4529 - acc: 0.7789 - val_loss: 3.4931 - val_acc: 0.7759
#
# Epoch 00043: val_loss did not improve
# Epoch 44/50
#  - 5s - loss: 3.4396 - acc: 0.7799 - val_loss: 3.4837 - val_acc: 0.7770
#
# Epoch 00044: val_loss did not improve
# Epoch 45/50
#  - 5s - loss: 3.4858 - acc: 0.7771 - val_loss: 3.5168 - val_acc: 0.7759
#
# Epoch 00045: val_loss did not improve
# Epoch 46/50
#  - 5s - loss: 3.4673 - acc: 0.7780 - val_loss: 3.5103 - val_acc: 0.7758
#
# Epoch 00046: val_loss did not improve
# Epoch 47/50
#  - 5s - loss: 3.4749 - acc: 0.7775 - val_loss: 3.5459 - val_acc: 0.7739
# Epoch 00047: val_loss did not improve
# Epoch 48/50
#  - 5s - loss: 3.4965 - acc: 0.7760 - val_loss: 3.5686 - val_acc: 0.7725
#
# Epoch 00048: val_loss did not improve
# Epoch 49/50
#  - 5s - loss: 3.5305 - acc: 0.7743 - val_loss: 3.5218 - val_acc: 0.7753
#
# Epoch 00049: val_loss did not improve
# Epoch 50/50
#  - 5s - loss: 3.4454 - acc: 0.7800 - val_loss: 3.5344 - val_acc: 0.7743
#
# Epoch 00050: val_loss did not improve

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('cnn_vgg16_model.best.hdf5')

# evaluate test accuracy
score = model.evaluate(features_test, y_test, verbose=0)
accuracy = 100*score[1]

# print test accuracy
print('Test accuracy: %.4f%%' % accuracy)
# Out:
# Test accuracy: 76.4900%
